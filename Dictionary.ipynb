# %%
#1
students={"Aarya":95,"Rohan":78,"Mahesh":91,"Mohan":78,"Rahul":76}
students
# Out:
# {'Aarya': 95, 'Rohan': 78, 'Mahesh': 91, 'Mohan': 78, 'Rahul': 76}

# %%
#2
students["Aarya"]
# Out:
# 95

# %%
#3
students["Frank"]=81
students
# Out:
# {'Aarya': 95, 'Rohan': 78, 'Mahesh': 91, 'Mohan': 78, 'Rahul': 76, 'Frank': 81}

# %%
#4
students["Aarya"]=96
students
# Out:
# {'Aarya': 96, 'Rohan': 78, 'Mahesh': 91, 'Mohan': 78, 'Rahul': 76, 'Frank': 81}

# %%
#5
del students["Frank"]
students
# Out:
# {'Aarya': 96, 'Rohan': 78, 'Mahesh': 91, 'Mohan': 78, 'Rahul': 76}

# %%
#6
students.keys()
# Out:
# dict_keys(['Aarya', 'Rohan', 'Mahesh', 'Mohan', 'Rahul'])

# %%
#7
students.values()
# Out:
# dict_values([96, 78, 91, 78, 76])

# %%
#8
for name,marks in students.items():
    print(name,marks)
# Out:
# Aarya 96
# Rohan 78
# Mahesh 91
# Mohan 78
# Rahul 76

# %%
#9
"Aarya" in students
# Out:
# True

# %%
#10
92 in students.values()
# Out:
# False

# %%
#11
students.get("Mohan","Student not found")
# Out:
# 78

# %%
#12
emp={"John":"HR","Sara":"IT","Mike":"Finance","Anna":"Marketing"}
emp
# Out:
# {'John': 'HR', 'Sara': 'IT', 'Mike': 'Finance', 'Anna': 'Marketing'}

# %%
#13
emp["Sara"]
# Out:
# 'IT'

# %%
#14
emp["Tom"]="IT"
emp
# Out:
# {'John': 'HR',
#  'Sara': 'IT',
#  'Mike': 'Finance',
#  'Anna': 'Marketing',
#  'Tom': 'IT'}

# %%
#15
emp["Mike"]="Operations"
emp
# Out:
# {'John': 'HR',
#  'Sara': 'IT',
#  'Mike': 'Operations',
#  'Anna': 'Marketing',
#  'Tom': 'IT'}

# %%
#16
emp.pop("Anna")
# Out:
# 'Marketing'

# %%
emp
# Out:
# {'John': 'HR', 'Sara': 'IT', 'Mike': 'Operations', 'Tom': 'IT'}

# %%
#17
sorted_asc_name=dict(sorted(emp.items()))
sorted_asc_name
# Out:
# {'John': 'HR', 'Mike': 'Operations', 'Sara': 'IT', 'Tom': 'IT'}

# %%
#18
sorted_asc_dept=dict(sorted(emp.items(),key=lambda x:x[1]))
sorted_asc_dept
# Out:
# {'John': 'HR', 'Sara': 'IT', 'Tom': 'IT', 'Mike': 'Operations'}

# %%
#19
sorted_desc_name=dict(sorted(emp.items(),reverse=True))
sorted_desc_name
# Out:
# {'Tom': 'IT', 'Sara': 'IT', 'Mike': 'Operations', 'John': 'HR'}

# %%
#20
sorted_desc_dept=dict(sorted(emp.items(),key=lambda x:x[1],reverse=True))
sorted_desc_dept
# Out:
# {'Mike': 'Operations', 'Sara': 'IT', 'Tom': 'IT', 'John': 'HR'}

# %%
#21
value_to_find="IT"
keys_with_value=[k for k,v in emp.items() if v==value_to_find]
keys_with_value
# Out:
# ['Sara', 'Tom']

# %%
#22
students
# Out:
# {'Aarya': 96, 'Rohan': 78, 'Mahesh': 91, 'Mohan': 78, 'Rahul': 76}

# %%
count_above_80=sum(1 for marks in students.values() if marks>80)
count_above_80
# Out:
# 2

# %%
#23
nested_students = {
    "Alice": {"age": 20, "grade": "A", "department": "CS"},
    "Bob": {"age": 21, "grade": "B", "department": "Math"},
    "Charlie": {"age": 19, "grade": "A+", "department": "Physics"}
}
nested_students
# Out:
# {'Alice': {'age': 20, 'grade': 'A', 'department': 'CS'},
#  'Bob': {'age': 21, 'grade': 'B', 'department': 'Math'},
#  'Charlie': {'age': 19, 'grade': 'A+', 'department': 'Physics'}}

# %%
#24
nested_students["Charlie"]["grade"]
# Out:
# 'A+'

# %%
#25
nested_students["Bob"]["department"]="Statisctics"
nested_students
# Out:
# {'Alice': {'age': 20, 'grade': 'A', 'department': 'CS'},
#  'Bob': {'age': 21, 'grade': 'B', 'department': 'Statisctics'},
#  'Charlie': {'age': 19, 'grade': 'A+', 'department': 'Physics'}}

# %%
#26
for name,info in nested_students.items():
    print(name,"->",info["grade"])
# Out:
# Alice -> A
# Bob -> B
# Charlie -> A+

# %%
#27
students2={"George":79,"Helen":88}
students2
# Out:
# {'George': 79, 'Helen': 88}

# %%
merged_students=students | students2
merged_students
# Out:
# {'Aarya': 96,
#  'Rohan': 78,
#  'Mahesh': 91,
#  'Mohan': 78,
#  'Rahul': 76,
#  'George': 79,
#  'Helen': 88}

# %%
#28
temp_dict={"a":1,"b":2}
temp_dict
# Out:
# {'a': 1, 'b': 2}

# %%
temp_dict.clear()
temp_dict
# Out:
# {}

# %%
#29
students
# Out:
# {'Aarya': 96, 'Rohan': 78, 'Mahesh': 91, 'Mohan': 78, 'Rahul': 76}

# %%
students_copy=students.copy()
students_copy["Aarya"]=95
students,students_copy
# Out:
# ({'Aarya': 96, 'Rohan': 78, 'Mahesh': 91, 'Mohan': 78, 'Rahul': 76},
#  {'Aarya': 95, 'Rohan': 78, 'Mahesh': 91, 'Mohan': 78, 'Rahul': 76})

# %%
#30
squares={x
