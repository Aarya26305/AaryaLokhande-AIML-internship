# %%
arr=[10,20,30,40,50]
arr[0]
# Out:
# 10

# %%
a=5
b=5
c=d+e
e=a+b
a
b
c
d
e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 a=5
#       2 b=5
# ----> 3 c=d+e
#       4 e=a+b
#       5 a
#
# NameError: name 'd' is not defined

# %%
a=5
a
# Out:
# 5

# %%
a = 5
print(type(a))
b = 5.0
print(type(b))
c = 2 + 4j
print(type(c))
s='Welcome'
type(s)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# str

# %%
a=[1,4,7,10]
type(a)
# Out:
# list

# %%
type(True)
# Out:
# bool

# %%
a=(2,4,6)
type(a)
# Out:
# tuple

# %%
r={1:a,2:b}
type(r)
r
# Out:
# {1: (2, 4, 6), 2: 5.0}

# %%
a=[1,2,3]
len(a)
# Out:
# 3

# %%
list=['apple','banana','grapes']
len(list)
# Out:
# 3

# %%
len(list[1])
# Out:
# 6
