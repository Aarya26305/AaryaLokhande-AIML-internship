# %%
# 1. Create a Pandas Series using a list of 5 random numbers and custom index names.
#     Then print the series and its data type.
import pandas as pd

# Create a Pandas Series with 5 random numbers and custom index
s = pd.Series([12, 25, 7, 18, 30], index=['a', 'b', 'c', 'd', 'e'])

# Print the series
print(s)

# Print the data type
print(type(s))
# Out:
# a    12
# b    25
# c     7
# d    18
# e    30
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# 2. Create a DataFrame with columns: "Student_Name", "Maths", "Science", "English".
#     Fill it with 5 sample student records and display the top 3 rows using head().
# Create the DataFrame
data = {
    "Student_Name": ["Aarya", "Rohan", "Sneha", "Kunal", "Priya"],
    "Maths": [85, 72, 92, 88, 76],
    "Science": [90, 82, 89, 73, 80],
    "English": [88, 75, 91, 84, 79]
}

df = pd.DataFrame(data)

# Display top 3 rows
print(df.head(3))
# Out:
#   Student_Name  Maths  Science  English
# 0        Aarya     85       90       88
# 1        Rohan     72       82       75
# 2        Sneha     92       89       91

# %%
# 3. Import a CSV file (use any sample dataset) into a DataFrame.
#     Display the number of rows and columns using shape, and print column names

# Import CSV file into DataFrame
df1 = pd.read_csv("train.csv")

# Display number of rows and columns
print("Rows and Columns:", df.shape)

# Print column names
print("Column Names:")
print(df1.columns)
# Out:
# Rows and Columns: (5, 4)
# Column Names:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
# 4. Add a new column named "Total_Marks" that sums all three subject scores.
#     Then create another column "Average" by dividing Total_Marks by 3.

df["Total_Marks"] = df["Maths"] + df["Science"] + df["English"]
df["Average"] = df["Total_Marks"] / 3

# Display the updated DataFrame
print(df)
# Out:
#   Student_Name  Maths  Science  English  Total_Marks    Average
# 0        Aarya     85       90       88          263  87.666667
# 1        Rohan     72       82       75          229  76.333333
# 2        Sneha     92       89       91          272  90.666667
# 3        Kunal     88       73       84          245  81.666667
# 4        Priya     76       80       79          235  78.333333

# %%
# 5. Introduce a missing value (NaN) in the "Science" column and then:
#     (a) Identify missing values using isnull()
#     (b) Replace the missing value with the column mean using fillna().

import numpy as np

df.loc[2, "Science"] = np.nan

print(df.isnull())

df["Science"] = df["Science"].fillna(df["Science"].mean())

print(df)
# Out:
#    Student_Name  Maths  Science  English  Total_Marks  Average
# 0         False  False    False    False        False    False
# 1         False  False    False    False        False    False
# 2         False  False     True    False        False    False
# 3         False  False    False    False        False    False
# 4         False  False    False    False        False    False
#   Student_Name  Maths  Science  English  Total_Marks    Average
# 0        Aarya     85    90.00       88          263  87.666667
# 1        Rohan     72    82.00       75          229  76.333333
# 2        Sneha     92    81.25       91          272  90.666667
# 3        Kunal     88    73.00       84          245  81.666667
# 4        Priya     76    80.00       79          235  78.333333

# %%
# 6. Filter and display all students whose "Average" score is greater than 75.

# Filter students with Average score greater than 75
filtered_df = df[df["Average"] > 75]

# Display the result
print(filtered_df)
# Out:
#   Student_Name  Maths  Science  English  Total_Marks    Average
# 0        Aarya     85    90.00       88          263  87.666667
# 1        Rohan     72    82.00       75          229  76.333333
# 2        Sneha     92    81.25       91          272  90.666667
# 3        Kunal     88    73.00       84          245  81.666667
# 4        Priya     76    80.00       79          235  78.333333

# %%
# 7. Sort the DataFrame by "Total_Marks" in descending order and show the top 3 performers

# Sort by Total_Marks in descending order
sorted_df = df.sort_values(by="Total_Marks", ascending=False)

# Display top 3 performers
print(sorted_df.head(3))
# Out:
#   Student_Name  Maths  Science  English  Total_Marks    Average
# 2        Sneha     92    81.25       91          272  90.666667
# 0        Aarya     85    90.00       88          263  87.666667
# 3        Kunal     88    73.00       84          245  81.666667

# %%
# 8. Group students based on their "English" score range (like above or below 70)
#     and find the mean of "Maths" and "Science" marks for each group.

# Create a new column for English score range
df["English_Group"] = np.where(df["English"] >= 70, "Above 70", "Below 70")

# Group by English score range and find mean of Maths and Science
grouped_result = df.groupby("English_Group")[["Maths", "Science"]].mean()

# Display the result
print(grouped_result)
# Out:
#                Maths  Science
# English_Group
# Above 70        82.6    81.25

# %%
# 9. Merge two DataFrames:
#     (a) One with "Student_Name" and "Total_Marks"
#     (b) Another with "Student_Name" and "Sports_Score"
#     Then create a new column "Overall_Score" = Total_Marks + Sports_Score

# DataFrame (a): Student_Name and Total_Marks
df_marks = df[["Student_Name", "Total_Marks"]]

# DataFrame (b): Student_Name and Sports_Score
sports_data = {
    "Student_Name": ["Aarya", "Rohan", "Sneha", "Kunal", "Priya"],
    "Sports_Score": [20, 18, 22, 19, 17]
}
df_sports = pd.DataFrame(sports_data)

# Merge the two DataFrames on Student_Name
merged_df = pd.merge(df_marks, df_sports, on="Student_Name")

# Create Overall_Score
merged_df["Overall_Score"] = merged_df["Total_Marks"] + merged_df["Sports_Score"]

# Display result
print(merged_df)
# Out:
#   Student_Name  Total_Marks  Sports_Score  Overall_Score
# 0        Aarya          263            20            283
# 1        Rohan          229            18            247
# 2        Sneha          272            22            294
# 3        Kunal          245            19            264
# 4        Priya          235            17            252

# %%
# 10. Export the final DataFrame to a CSV file on your Desktop (use os library to define path)
#     and verify if the file is successfully created using os.path.exists().

# Export DataFrame to CSV
merged_df.to_csv('Pandas_Assignment1.csv', index=False)

# Verify if file exists
if os.path.exists(Pandas_Assignment1.csv'):
    print("File successfully created at:", file_path)
else:
    print("File creation failed.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       1 # 10. Export the final DataFrame to a CSV file on your Desktop (use os library to define path)
#       2 #     and verify if the file is successfully created using os.path.exists().
#       3
#       4 # Export DataFrame to CSV
# ----> 5 merged_df.to_csv(file_path, index=False)
#       7 # Verify if file exists
#       8 if os.path.exists(file_path):
#
# NameError: name 'file_path' is not defined
